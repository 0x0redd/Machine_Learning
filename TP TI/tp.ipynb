# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('lena.png')
rows, cols = img.shape[:2]

# %%
M = np.float32([[1, 0, 50], [0, 1, 30]])
translated = cv2.warpAffine(img, M, (cols, rows))

# %%
plt.subplot(1, 2, 1), plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)), plt.title('Originale')
plt.subplot(1, 2, 2), plt.imshow(cv2.cvtColor(translated, cv2.COLOR_BGR2RGB)), plt.title('Translatée')
plt.show()

# %%
reduced = cv2.resize(img, (0,0), fx=0.5, fy=0.5)

zoomed = cv2.resize(img, (0,0), fx=0.5, fy=0.5)

# %%
center = (cols // 2, rows // 2)
M = cv2.getRotationMatrix2D(center, 45, 1.0)
rotated = cv2.warpAffine(img, M, (cols, rows))

# %%
plt.imshow(cv2.cvtColor(rotated, cv2.COLOR_BGR2RGB)), plt.title('Rotation 45°')
plt.show()

# %%
A = cv2.imread('A.png', 0)
B = cv2.imread('B.png', 0)

# %%
add = cv2.add(A, B)
sub_AB = cv2.subtract(A, B)
sub_BA = cv2.subtract(B, A)
bitwise_and = cv2.bitwise_and(A, cv2.bitwise_not(A))
bitwise_or = cv2.bitwise_or(A, B)

# %%
import cv2
img = cv2.imread('test.jpg')
print(img)
# Out:
# [[[  0   0   0]
#   [  0   0   0]
#   [254 254 254]
#   [254 254 254]]
#
#  [[  0   0   0]
#   [  0   0   0]
#   [254 254 254]
#   [254 254 254]]
#
#  [[255 255 255]
#   [254 254 254]
#   [  1   1   1]
#   [  1   1   1]]
#
#  [[253 253 253]
#   [253 253 253]
#   [ 11  11  11]
#   [  1   1   1]]]

# %%
img = cv2.imread('lena.png')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('lena.png')
img_reduced = cv2.resize(img, None, fx=0.5, fy=0.5)
img_enlarged = cv2.resize(img, None, fx=1.9, fy=1.9)

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Original")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(cv2.cvtColor(img_reduced, cv2.COLOR_BGR2RGB))
plt.title("Réduction (à 50%)")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(img_enlarged, cv2.COLOR_BGR2RGB))
plt.title("Agrandissement (à 190%)")
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Original")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(cv2.cvtColor(img_opencv, cv2.COLOR_BGR2RGB))
plt.title("OpenCV Resize (50%)")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(img_manual, cv2.COLOR_BGR2RGB))
plt.title("Manual Nearest Neighbor (50%)")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 14
#      11 plt.axis('off')
#      13 plt.subplot(1, 3, 3)
# ---> 14 plt.imshow(cv2.cvtColor(img_manual, cv2.COLOR_BGR2RGB))
#      15 plt.title("Manual Nearest Neighbor (50%)")
#      16 plt.axis('off')
#
# NameError: name 'img_manual' is not defined
